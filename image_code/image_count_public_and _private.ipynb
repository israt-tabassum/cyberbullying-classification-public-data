# %% [markdown]
# # Public data

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Define paths to your dataset
train_path = '/content/drive/My Drive/Colab Notebooks/public-data/image/dataset/train'
valid_path = '/content/drive/My Drive/Colab Notebooks/public-data/image/dataset/val'
test_path = '/content/drive/My Drive/Colab Notebooks/public-data/image/dataset/test'

# Function to analyze dataset
def analyze_dataset(path):
    class_counts = Counter()
    for class_dir in os.listdir(path):
        class_path = os.path.join(path, class_dir)
        if os.path.isdir(class_path):
            count = len(os.listdir(class_path))
            class_counts[class_dir] = count
    return class_counts

# Call analyze_dataset for each dataset category and print the results
train_class_counts = analyze_dataset(train_path)
valid_class_counts = analyze_dataset(valid_path)
test_class_counts = analyze_dataset(test_path)

# Print out the counts
print("Training dataset class counts:", train_class_counts)
print("Validation dataset class counts:", valid_class_counts)
print("Test dataset class counts:", test_class_counts)



# Combine all counts to get a grand total per class
grand_total_counts = train_class_counts + valid_class_counts + test_class_counts
print("Grand total class counts across all datasets:", grand_total_counts)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Training dataset class counts: Counter({'0': 1635, '1': 1635, '2': 1635, '3': 1635})
# Validation dataset class counts: Counter({'0': 205, '1': 205, '2': 205, '3': 205})
# Test dataset class counts: Counter({'0': 204, '1': 204, '2': 204, '3': 204})
# Grand total class counts across all datasets: Counter({'0': 2044, '1': 2044, '2': 2044, '3': 2044})

# %%
# Define paths to our dataset
train_path_1 = '/content/drive/My Drive/Colab Notebooks/private-data/image/dataset/train'
valid_path_1 = '/content/drive/My Drive/Colab Notebooks/private-data/image/dataset/val'
test_path_1 = '/content/drive/My Drive/Colab Notebooks/private-data/image/dataset/test'


# Function to analyze dataset
def analyze_dataset_1(path):
    class_counts = Counter()
    for class_dir in os.listdir(path):
        class_path = os.path.join(path, class_dir)
        if os.path.isdir(class_path):
            count = len(os.listdir(class_path))
            class_counts[class_dir] = count
    return class_counts

# Call analyze_dataset for each dataset category and print the results
train_class_counts_1 = analyze_dataset_1(train_path_1)
valid_class_counts_1 = analyze_dataset_1(valid_path_1)
test_class_counts_1 = analyze_dataset_1(test_path_1)

# Print out the counts
print("Training dataset class counts:", train_class_counts_1)
print("Validation dataset class counts:", valid_class_counts_1)
print("Test dataset class counts:", test_class_counts_1)



# Combine all counts to get a grand total per class
grand_total_counts_1 = train_class_counts_1 + valid_class_counts_1 + test_class_counts_1
print("Grand total class counts across all datasets:", grand_total_counts_1)
# Out:
# Training dataset class counts: Counter({'0': 205, '1': 205, '2': 205, '3': 205})
# Validation dataset class counts: Counter({'0': 26, '1': 26, '2': 26, '3': 26})
# Test dataset class counts: Counter({'0': 26, '2': 26, '3': 26, '1': 25})
# Grand total class counts across all datasets: Counter({'0': 257, '2': 257, '3': 257, '1': 256})
